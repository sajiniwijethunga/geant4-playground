# %%
import numpy as np
import matplotlib.pyplot as plt


import uproot
import awkward as ak
import hist
from hist import Hist

# %%
file = uproot.open("build/sagini.root")

file.keys()
# Out:
# ['h1;1', 'h2;1', 'h3;1', 'h10;1', 'h20;1', 'h30;1', 'h40;1']

# %%
h1 = file["h1"].to_hist()

# %%
h1.plot()
plt.xlabel("energy deposit in absorber")
plt.ylabel("dN/dE")
plt.show()
